# %% [markdown]
# # In this notebook were going to conduct some exploratory data analysis on a housing market of kings county USA. This dataset has been taken from kaggle datasets

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('kc_house_data.csv')

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
#lets see if we have any null entries in the dataframe
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# Descr:there are no null entries in this dataset

# %%
#lets carry out a statistical analysis of the data
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     21597.0  7.547345e-03  8.654900e-02  0.000000e+00
# view           21597.0  2.342918e-01  7.663898e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# sqft_basement  21597.0  2.917250e+02  4.426678e+02  0.000000e+00
# ...

# %%
#lets look at the price distribution of the houses
plt.figure(figsize=(12,8))
sns.distplot(df['price'],kde=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#now lets look at the number of bedrooms of the houses
plt.figure(figsize=(12,8))
sns.countplot(df['bedrooms'],data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# This shows taht there are houses tat have 13 bedrooms

# %%
#lets look at the correlation
df.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016772  0.001150   0.005162    -0.012241 -0.131911
# price         -0.016772  1.000000  0.308787   0.525906     0.701917  0.089876
# bedrooms       0.001150  0.308787  1.000000   0.514508     0.578212  0.032471
# bathrooms      0.005162  0.525906  0.514508   1.000000     0.755758  0.088373
# sqft_living   -0.012241  0.701917  0.578212   0.755758     1.000000  0.173453
# sqft_lot      -0.131911  0.089876  0.032471   0.088373     0.173453  1.000000
# floors         0.018608  0.256804  0.177944   0.502582     0.353953 -0.004814
# waterfront    -0.002727  0.266398 -0.006834   0.063744     0.103854  0.021632
# view           0.011536  0.397370  0.080008   0.188386     0.284709  0.074900
# condition     -0.023803  0.036056  0.026496  -0.126479    -0.059445 -0.008830
# grade          0.008188  0.667951  0.356563   0.665838     0.762779  0.114731
# ...

# %%
df.corr()['price']
#here we see the correlation of price with other features, obviously the correllation with the price would be 1
# Out:
# id              -0.016772
# price            1.000000
# bedrooms         0.308787
# bathrooms        0.525906
# sqft_living      0.701917
# sqft_lot         0.089876
# floors           0.256804
# waterfront       0.266398
# view             0.397370
# condition        0.036056
# grade            0.667951
# sqft_above       0.605368
# sqft_basement    0.323799
# yr_built         0.053953
# yr_renovated     0.126424
# zipcode         -0.053402
# lat              0.306692
# long             0.022036
# sqft_living15    0.585241
# sqft_lot15       0.082845
# Name: price, dtype: float64

# %%
#to sort it by values we do
df.corr()['price'].sort_values()
# Out:
# zipcode         -0.053402
# id              -0.016772
# long             0.022036
# condition        0.036056
# yr_built         0.053953
# sqft_lot15       0.082845
# sqft_lot         0.089876
# yr_renovated     0.126424
# floors           0.256804
# waterfront       0.266398
# lat              0.306692
# bedrooms         0.308787
# sqft_basement    0.323799
# view             0.397370
# bathrooms        0.525906
# sqft_living15    0.585241
# sqft_above       0.605368
# grade            0.667951
# sqft_living      0.701917
# price            1.000000
# Name: price, dtype: float64

# %% [markdown]
# **From the above information it is evident that sqft_living has a high correlation with the price of the house**

# %%
#the above can be proved by a scatter plot of the price with sqft
plt.figure(figsize=(10,8))
sns.scatterplot(df['price'],df['sqft_living'],data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#to check the variation of prices we can do a boxplot of the price with the number of bedrooms
plt.figure(figsize=(12,8))
sns.boxplot(df['bedrooms'],df['price'],data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Lets take a look how prices are effected depending upon the longitude and the latitude

# %%
#lets do a scatter plot with respect to the price and latitude
plt.figure(figsize=(12,8))
sns.scatterplot(df['price'],df['lat'],data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Descr: we can see a price rise where latitude is approximately 47.6

# %%
#lets plot the longitude
plt.figure(figsize=(12,8))
sns.scatterplot(df['price'],df['long'],data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Descr: we see a rise in the price where the latitude is -122.2

# %% [markdown]
# **we can replicate the map by the longitude and latitude points by the scatterplot**

# %%
plt.figure(figsize=(14,10))
plt.title("Replicating the map of Kings county")
sns.scatterplot(df['long'],df['lat'],data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#lets highlight the map by the hue where prices take a shift
plt.figure(figsize=(14,10))
sns.scatterplot(df['long'],df['lat'],data=df,hue=df['price'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#the above map is not that clear so we change the colors a little bit
plt.figure(figsize=(14,10))
sns.scatterplot(df['long'],df['lat'],data=df,hue=df['price'],palette="RdYlGn",alpha=0.2,edgecolor=None)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **We can see in this plot that the longitude and the latitude that were correlating to a hgh price show up at the same long and lat values**

# %%
#lets look at the map again after dropping some outliers
#to view the outliers lets look at the prices of the 20 most expensive houses
df.sort_values('price',ascending=False).head(20)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245   6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910   9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245   9208900037   9/19/2014  6890000.0         6       7.75         9890
# 4407   2470100110    8/4/2014  5570000.0         5       5.75         9200
# 1446   8907500070   4/13/2015  5350000.0         5       5.00         8000
# 1313   7558700030   4/13/2015  5300000.0         6       6.00         7390
# 1162   1247600105  10/20/2014  5110000.0         5       5.25         8010
# 8085   1924059029   6/17/2014  4670000.0         5       6.75         9640
# 2624   7738500731   8/15/2014  4500000.0         5       5.50         6640
# 8629   3835500195   6/18/2014  4490000.0         4       3.00         6430
# 12358  6065300370    5/6/2015  4210000.0         5       6.00         7440
# ...

# %% [markdown]
# **We can see taht the price drops from 77 million to 3.6 million when viewing the 20 most expensive houses**

# %% [markdown]
# **lets drop off the top 1 percent (most expensive) houses so we can see where amjority of our houses lie**

# %%
#the length of the dataframe is 
len(df)
# Out:
# 21597

# %%
print("top 1 percesnt includes",len(df)*0.01,"houses")
# Out:
# top 1 percesnt includes 215.97 houses

# %%
#so lets seperate out a new dataframe taht has houses other than these top one percent houses
not_top_1_perc=df.sort_values('price',ascending=False).iloc[216:]

# %%
not_top_1_perc['price'].max()
# Out:
# 1970000.0

# %% [markdown]
# **Desc: this new dataframe includes 99% of our dataset and does not include those explensive outliers**

# %%
#lets look at the map again

plt.figure(figsize=(14,10))
sns.scatterplot(df['long'],df['lat'],data=not_top_1_perc,hue='price',palette="RdYlGn",alpha=0.2,edgecolor=None)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **This map evidently proves that the properties near the waterfront are more expensive**

# %%
sns.boxplot(df['waterfront'],df['price'],data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
#lets drop the id column
df=df.drop('id',axis=1)

# %%
df
# Out:
#              date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      10/13/2014  221900.0         3       1.00         1180      5650
# 1       12/9/2014  538000.0         3       2.25         2570      7242
# 2       2/25/2015  180000.0         2       1.00          770     10000
# 3       12/9/2014  604000.0         4       3.00         1960      5000
# 4       2/18/2015  510000.0         3       2.00         1680      8080
# ...           ...       ...       ...        ...          ...       ...
# 21592   5/21/2014  360000.0         3       2.50         1530      1131
# 21593   2/23/2015  400000.0         4       2.50         2310      5813
# 21594   6/23/2014  402101.0         2       0.75         1020      1350
# 21595   1/16/2015  400000.0         3       2.50         1600      2388
# 21596  10/15/2014  325000.0         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
#lets view the date column
df['date']
# Out:
# 0        10/13/2014
# 1         12/9/2014
# 2         2/25/2015
# 3         12/9/2014
# 4         2/18/2015
#             ...
# 21592     5/21/2014
# 21593     2/23/2015
# 21594     6/23/2014
# 21595     1/16/2015
# 21596    10/15/2014
# Name: date, Length: 21597, dtype: object

# %%
#as we can see its not a date object , lets convert into a date object
df['date']=pd.to_datetime(df['date'])

# %%
df['date']
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21592   2014-05-21
# 21593   2015-02-23
# 21594   2014-06-23
# 21595   2015-01-16
# 21596   2014-10-15
# Name: date, Length: 21597, dtype: datetime64[ns]

# %%
#as we can see now the date is converted to a date time object now,
#lets create new column of year and month
df['year']=df['date'].apply(lambda Date: Date.year)
df
# Out:
#             date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0     2014-10-13  221900.0         3       1.00         1180      5650
# 1     2014-12-09  538000.0         3       2.25         2570      7242
# 2     2015-02-25  180000.0         2       1.00          770     10000
# 3     2014-12-09  604000.0         4       3.00         1960      5000
# 4     2015-02-18  510000.0         3       2.00         1680      8080
# ...          ...       ...       ...        ...          ...       ...
# 21592 2014-05-21  360000.0         3       2.50         1530      1131
# 21593 2015-02-23  400000.0         4       2.50         2310      5813
# 21594 2014-06-23  402101.0         2       0.75         1020      1350
# 21595 2015-01-16  400000.0         3       2.50         1600      2388
# 21596 2014-10-15  325000.0         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  ...  sqft_above  sqft_basement  \
# ...

# %%
#now lets create a column for the month
df['month']=df['date'].apply(lambda Date: Date.month)

# %%
df
# Out:
#             date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0     2014-10-13  221900.0         3       1.00         1180      5650
# 1     2014-12-09  538000.0         3       2.25         2570      7242
# 2     2015-02-25  180000.0         2       1.00          770     10000
# 3     2014-12-09  604000.0         4       3.00         1960      5000
# 4     2015-02-18  510000.0         3       2.00         1680      8080
# ...          ...       ...       ...        ...          ...       ...
# 21592 2014-05-21  360000.0         3       2.50         1530      1131
# 21593 2015-02-23  400000.0         4       2.50         2310      5813
# 21594 2014-06-23  402101.0         2       0.75         1020      1350
# 21595 2015-01-16  400000.0         3       2.50         1600      2388
# 21596 2014-10-15  325000.0         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  ...  sqft_basement  yr_built  \
# ...

# %%
#lets look at the variation of prices through a boxplot w.r.t months
plt.figure(figsize=(12,10))
sns.boxplot(x='month',y='price',data=df)

# %%
#lets look at the price w.r.t the month
df.groupby('month').mean()['price']
# Out:
# month
# 1     525963.251534
# 2     508520.051323
# 3     544057.683200
# 4     562215.615074
# 5     550849.746893
# 6     557534.318182
# 7     544892.161013
# 8     536655.212481
# 9     529723.517787
# 10    539439.447228
# 11    522359.903478
# 12    524799.902041
# Name: price, dtype: float64

# %%
df.groupby('month').mean()['price'].plot()

# %%
#we can also plot the variation of the price by the year
df.groupby('year').mean()['price'].plot()

# %%
#lets drop the date column since its no longer useful
df=df.drop(['date'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-c43490a0be18> in <module>()
#       1 #lets drop the date column since its no longer useful
# ----> 2 df=df.drop(['date'],axis=1)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0         3       1.00         1180      5650     1.0
# 1      538000.0         3       2.25         2570      7242     2.0
# 2      180000.0         2       1.00          770     10000     1.0
# 3      604000.0         4       3.00         1960      5000     1.0
# 4      510000.0         3       2.00         1680      8080     1.0
# ...         ...       ...        ...          ...       ...     ...
# 21592  360000.0         3       2.50         1530      1131     3.0
# 21593  400000.0         4       2.50         2310      5813     2.0
# 21594  402101.0         2       0.75         1020      1350     2.0
# 21595  400000.0         3       2.50         1600      2388     2.0
# 21596  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  ...  sqft_basement  yr_built  \
# 0               0     0          3      7  ...              0      1955
# ...

# %%
plt.figure(figsize=(17,10))
sns.countplot(x='zipcode',data=df)

# %%
df['zipcode'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0        98178
# 1        98125
# 2        98028
# 3        98136
# 4        98074
#          ...
# 21592    98103
# 21593    98146
# 21594    98144
# 21595    98027
# 21596    98144
# Name: zipcode, Length: 21597, dtype: int64>

# %%
df['zipcode'].value_counts()
# Out:
# 98103    602
# 98038    589
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    104
# 98010    100
# 98024     80
# 98148     57
# 98039     50
# Name: zipcode, Length: 70, dtype: int64

# %%
#there. are 70 zipcodes , so well drop it because its too large
df=df.drop(['zipcode'],axis=1)
df
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0         3       1.00         1180      5650     1.0
# 1      538000.0         3       2.25         2570      7242     2.0
# 2      180000.0         2       1.00          770     10000     1.0
# 3      604000.0         4       3.00         1960      5000     1.0
# 4      510000.0         3       2.00         1680      8080     1.0
# ...         ...       ...        ...          ...       ...     ...
# 21592  360000.0         3       2.50         1530      1131     3.0
# 21593  400000.0         4       2.50         2310      5813     2.0
# 21594  402101.0         2       0.75         1020      1350     2.0
# 21595  400000.0         3       2.50         1600      2388     2.0
# 21596  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0               0     0          3      7        1180              0
# ...

# %%
plt.figure(figsize=(12,10))
sns.scatterplot('yr_renovated','price',data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df.corr()['price'].sort_values(ascending=False)
# Out:
# price            1.000000
# sqft_living      0.701917
# grade            0.667951
# sqft_above       0.605368
# sqft_living15    0.585241
# bathrooms        0.525906
# view             0.397370
# sqft_basement    0.323799
# bedrooms         0.308787
# lat              0.306692
# waterfront       0.266398
# floors           0.256804
# yr_renovated     0.126424
# sqft_lot         0.089876
# sqft_lot15       0.082845
# yr_built         0.053953
# condition        0.036056
# long             0.022036
# year             0.003727
# month           -0.009928
# Name: price, dtype: float64

# %%
df[df['yr_renovated']==0].max()['price']
# Out:
# 6890000.0

# %% [markdown]
# # Lets make the model

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Dense

# %%
#our features would be the entire dataset except fro the price column
X=df.drop(['price'],axis=1).values

# %%
X
# Out:
# array([[3.000e+00, 1.000e+00, 1.180e+03, ..., 5.650e+03, 2.014e+03,
#         1.000e+01],
#        [3.000e+00, 2.250e+00, 2.570e+03, ..., 7.639e+03, 2.014e+03,
#         1.200e+01],
#        [2.000e+00, 1.000e+00, 7.700e+02, ..., 8.062e+03, 2.015e+03,
#         2.000e+00],
#        ...,
#        [2.000e+00, 7.500e-01, 1.020e+03, ..., 2.007e+03, 2.014e+03,
#         6.000e+00],
#        [3.000e+00, 2.500e+00, 1.600e+03, ..., 1.287e+03, 2.015e+03,
#         1.000e+00],
#        [2.000e+00, 7.500e-01, 1.020e+03, ..., 1.357e+03, 2.014e+03,
#         1.000e+01]])

# %%
#our label would be the price
y=df['price'].values
y
# Out:
# array([221900., 538000., 180000., ..., 402101., 400000., 325000.])

# %%
type(y)
# Out:
# numpy.ndarray

# %%
#lets do the train test split, for that well need sklearn
# !pip install sklearn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=101)

# %%
scaler=MinMaxScaler()

# %%
X_train=scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %%
X_train.shape
# Out:
# (15117, 19)

# %%
#lets make a sequential model
model=Sequential()
model.add(Dense(19,activation='relu'))

model.add(Dense(19,activation='relu'))

model.add(Dense(19,activation='relu'))

model.add(Dense(19,activation='relu'))

model.add(Dense(1))
model.compile(optimizer='adam',loss='mse')

# %%
model.fit(X_train,y_train,batch_size=128,epochs=400,validation_data=(X_test,y_test))
# Out:
# Epoch 1/400
# 119/119 [==============================] - 2s 4ms/step - loss: 430242103296.0000 - val_loss: 418930425856.0000
# Epoch 2/400
# 119/119 [==============================] - 0s 3ms/step - loss: 429505085440.0000 - val_loss: 416444809216.0000
# Epoch 3/400
# 119/119 [==============================] - 0s 3ms/step - loss: 419829776384.0000 - val_loss: 394317201408.0000
# Epoch 4/400
# 119/119 [==============================] - 0s 3ms/step - loss: 370776211456.0000 - val_loss: 311110074368.0000
# Epoch 5/400
# 119/119 [==============================] - 0s 3ms/step - loss: 249588858880.0000 - val_loss: 167957151744.0000
# Epoch 6/400
# 119/119 [==============================] - 0s 3ms/step - loss: 129276534784.0000 - val_loss: 99233873920.0000
# Epoch 7/400
# 119/119 [==============================] - 0s 3ms/step - loss: 99644743680.0000 - val_loss: 94667898880.0000
# Epoch 8/400
# ...

# %% [markdown]
# # Lets evaluate our model

# %%
#so we can use model.history.history
model.history.history
# Out:
# {'loss': [430242103296.0,
#   429505085440.0,
#   419829776384.0,
#   370776211456.0,
#   249588858880.0,
#   129276534784.0,
#   99644743680.0,
#   96980066304.0,
#   95104516096.0,
#   93168254976.0,
#   91169570816.0,
#   89040404480.0,
#   86925131776.0,
#   84674084864.0,
#   82309611520.0,
#   79804997632.0,
#   77137682432.0,
#   74406273024.0,
#   71610384384.0,
#   68788404224.0,
#   65968005120.0,
#   63216852992.0,
#   60664889344.0,
#   58299314176.0,
#   56274116608.0,
#   54511849472.0,
#   53083914240.0,
#   51922354176.0,
#   50886103040.0,
#   50079064064.0,
#   49334472704.0,
#   48693723136.0,
#   48044204032.0,
#   47472451584.0,
#   46954033152.0,
#   46421749760.0,
#   45949984768.0,
#   45456752640.0,
#   45035921408.0,
#   44547309568.0,
#   44085047296.0,
#   43670241280.0,
#   43239395328.0,
#   42822021120.0,
#   42417188864.0,
#   41994940416.0,
#   41570111488.0,
#   41224740864.0,
#   40827899904.0,
#   40465276928.0,
#   40144244736.0,
# ...

# %%
#we can convert this loss history to a dataframe
losses=pd.DataFrame(model.history.history)

# %%
losses
# Out:
#              loss      val_loss
# 0    4.302421e+11  4.189304e+11
# 1    4.295051e+11  4.164448e+11
# 2    4.198298e+11  3.943172e+11
# 3    3.707762e+11  3.111101e+11
# 4    2.495889e+11  1.679572e+11
# ..            ...           ...
# 395  2.560119e+10  2.367093e+10
# 396  2.560487e+10  2.370750e+10
# 397  2.552962e+10  2.363526e+10
# 398  2.547846e+10  2.358573e+10
# 399  2.546375e+10  2.353959e+10
#
# [400 rows x 2 columns]

# %%
#we get two columns one for training loss and one for validation
#now lets plot it 
losses.plot()

# %%
#for our metrics we can use sklearn.metrics
from sklearn.metrics import mean_squared_error,mean_absolute_error,explained_variance_score

# %%
predictions=model.predict(X_test)

# %%
np.sqrt(mean_squared_error(y_test,predictions))
# Out:
# 153426.16042089742

# %%
mean_absolute_error(y_test,predictions)
# Out:
# 92210.11615427276

# %%
explained_variance_score(y_test,predictions)
# Out:
# 0.8225164450191711

# %%
#our model could be trained more
#lets see a plot of out current predictions and y_test
plt.figure(figsize=(12,10))
plt.scatter(y_test,predictions)
plt.plot(y_test,y_test,'r')

# %% [markdown]
# **These outliers at the end are whats causing the errors, we are pretty good at predicting the price of houses upto 2000000 dollars**

# %% [markdown]
# # Lets do a predtiction of one of the houses

# %%
#to get one house from the dataset we have to drop the houses price
single_home=df.drop(['price'],axis=1).iloc[0]

# %%
single_home
# Out:
# bedrooms            3.0000
# bathrooms           1.0000
# sqft_living      1180.0000
# sqft_lot         5650.0000
# floors              1.0000
# waterfront          0.0000
# view                0.0000
# condition           3.0000
# grade               7.0000
# sqft_above       1180.0000
# sqft_basement       0.0000
# yr_built         1955.0000
# yr_renovated        0.0000
# lat                47.5112
# long             -122.2570
# sqft_living15    1340.0000
# sqft_lot15       5650.0000
# year             2014.0000
# month              10.0000
# Name: 0, dtype: float64

# %%
#now lets transform it
single_home=scaler.transform(single_home.values.reshape(-1,19))

# %%
model.predict(single_home)
# Out:
# array([[291387.22]], dtype=float32)

# %%
one_more_home=df.drop(['price'],axis=1).iloc[2]

# %%
one_more_home=one_more_home.values

# %%
#the above statement converts it to an array
one_more_home
# Out:
# array([ 2.00000e+00,  1.00000e+00,  7.70000e+02,  1.00000e+04,
#         1.00000e+00,  0.00000e+00,  0.00000e+00,  3.00000e+00,
#         6.00000e+00,  7.70000e+02,  0.00000e+00,  1.93300e+03,
#         0.00000e+00,  4.77379e+01, -1.22233e+02,  2.72000e+03,
#         8.06200e+03,  2.01500e+03,  2.00000e+00])

# %%
#so its not a 2-d array , we can convert it
one_more_home=one_more_home.reshape(-1,19)

# %%
one_more_home
# Out:
# array([[ 2.00000e+00,  1.00000e+00,  7.70000e+02,  1.00000e+04,
#          1.00000e+00,  0.00000e+00,  0.00000e+00,  3.00000e+00,
#          6.00000e+00,  7.70000e+02,  0.00000e+00,  1.93300e+03,
#          0.00000e+00,  4.77379e+01, -1.22233e+02,  2.72000e+03,
#          8.06200e+03,  2.01500e+03,  2.00000e+00]])

# %%
one_more_home=scaler.transform(one_more_home)
one_more_home
# Out:
# array([[0.1       , 0.08      , 0.04136505, 0.00574253, 0.        ,
#         0.        , 0.        , 0.5       , 0.3       , 0.05326232,
#         0.        , 0.28695652, 0.        , 0.93614283, 0.23754153,
#         0.3994149 , 0.00863351, 1.        , 0.09090909]])

# %%
#now its ready for prediction
model.predict(one_more_home)
# Out:
# array([[349978.4]], dtype=float32)
